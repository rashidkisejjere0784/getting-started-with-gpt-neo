# %% [markdown]
# <a href="https://colab.research.google.com/github/rashidkisejjere0784/getting-started-with-gpt-neo/blob/main/Gpt_neo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 46.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 19.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 60.8 MB/s eta 0:00:00
# ...

# %%
from transformers import GPTNeoForCausalLM, GPT2Tokenizer

# %%
model = GPTNeoForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")
# Out:
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.31G [00:00<?, ?B/s]

# %%
tokenizer = GPT2Tokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B")
# Out:
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/200 [00:00<?, ?B/s]

# %%
Prompt = ("what is life and why is it that ")

# %%
input_ids = tokenizer(Prompt, return_tensors="pt").input_ids

# %%
gen_tokens = model.generate(input_ids, max_length = 100)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(tokenizer.batch_decode(gen_tokens)[0])
# Out:
# what is life and why is it that
# I am not a part of it?
#
# I am not a part of it because I am not a part of it.
#
# I am not a part of it because I am not a part of it.
#
# I am not a part of it because I am not a part of it.
#
# I am not a part of it because I am not a part of it.
#
# I am not a part of it
